# %%
age=19
if age <18:
    print("cannot vote")

elif age==18:
    print("can vote")

else:
    print(" can vote")
# Out:
#  can vote

# %%
#nested if codes
s=int(input("enter your score"))
a=int(input("enter attendance"))

if s>=70:
    print("passed")
else:
    print("failed")    

if a>=90:
    print("excellent attendance")
else:
    print("attendence could be improved")
# Out:
# enter your score 90
# enter attendance 90
# passed
# excellent attendance

# %%
#looping
n=int(input("enter no"))
for i in range(n):
    for j in range(i+1):
        print("*", end="")
    print()
# Out:
# enter no 5
# *
# **
# ***
# ****
# *****

# %%
n=int(input("enter no"))
for i in range(n):
    for j in range(i+1,n):
        print("*", end="")
    print()
# Out:
# enter no 6
# *****
# ****
# ***
# **
# *
